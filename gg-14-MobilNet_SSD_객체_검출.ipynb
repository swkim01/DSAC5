# %% [markdown]
# <h1>MobilNet SSD 객체 검출</h1>
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/swkim01/DSAC5/blob/main/gg-14-MobilNet_SSD_객체_검출.ipynb"><img src="https://github.com/swkim01/DSAC5/raw/main/colab_logo_32px.png" />구글 코랩에서 실행</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/swkim01/DSAC5/blob/main/gg-14-MobilNet_SSD_객체_검출.ipynb"><img src="https://github.com/swkim01/DSAC5/raw/main/GitHub-Mark-32px.png" />깃헙에서 소스 보기</a>
#   </td>
# </table>

# %% [markdown]
# • 동영상 인식에 대한 이해를 돕기 위해 MobilNet SSD로 미리 학습된 모델을 실행하여 보도록 한다.<br>
# • 이미 학습된 모델이기 때문에 해당 명령어만으로도 실행이 가능하다.<br>
# • 본 코드는 동영상 내에서 인식된 결과중 한 부분을 캡쳐하여 출력해준다.

# %% [markdown]
# 실습예제의 MobilNet_SSD_opencv-master.zip 파일을 코랩 환경의 '/content/sample_data'로 업로드한다.

# %%
# %%shell
# unzip '/content/sample_data/MobilNet_SSD_opencv-master.zip'
# Out:
# Archive:  /content/sample_data/MobilNet_SSD_opencv-master.zip
#   inflating: img.jpeg
#   inflating: MobileNetSSD_deploy.caffemodel
#   inflating: MobileNetSSD_deploy.prototxt
#   inflating: mobilenet_ssd_python.py
#   inflating: motor_bike.mp4
#   inflating: README.md
#   inflating: sample_img.py

# %%
# %%shell
# python /content/mobilenet_ssd_python.py --video /content/motor_bike.mp4  --prototxt /content/MobileNetSSD_deploy.prototxt --weight /content/MobileNetSSD_deploy.caffemodel
# Out:
# video is available..
# finish!

# %%
from IPython.display import Image
Image('/content/frame.png')
