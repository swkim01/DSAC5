# %% [markdown]
# # YOLO V3
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/swkim01/DSAC5/blob/main/gg-20-yolov3.ipynb"><img src="https://github.com/swkim01/DSAC5/raw/main/colab_logo_32px.png" />구글 코랩에서 실행</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/swkim01/DSAC5/blob/main/gg-20-yolov3.ipynb"><img src="https://github.com/swkim01/DSAC5/raw/main/GitHub-Mark-32px.png" />깃헙에서 소스 보기</a>
#   </td>
# </table>

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# %cd yolov3
#!git checkout tags/v8
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10079, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 10079 (delta 30), reused 30 (delta 13), pack-reused 10017
# Receiving objects: 100% (10079/10079), 9.39 MiB | 27.41 MiB/s, done.
# Resolving deltas: 100% (6789/6789), done.
# /content/yolov3

# %%
#!chmod +x weights/download_yolov3_weights.sh

# %%
#!weights/download_yolov3_weights.sh
# Out:
# ...
# 100% 119M/119M [00:01<00:00, 67.4MB/s]
#
# ...
# 100% 121M/121M [00:01<00:00, 82.4MB/s]
#
# ...
# 100% 17.0M/17.0M [00:00<00:00, 40.4MB/s]

# %%
#!python3 detect.py --cfg cfg/yolov3-spp.cfg --weights weights/yolov3-spp.weights
# !python3 detect.py --weights weights/yolov3-spp.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['weights/yolov3-spp.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-32-gae460cf torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
# 100% 121M/121M [00:00<00:00, 246MB/s]
#
# Fusing layers...
# Model Summary: 269 layers, 62971933 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, Done. (0.056s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 3 ties, 1 tennis racket, Done. (0.048s)
# Speed: 0.6ms pre-process, 51.6ms inference, 10.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from IPython.display import Image
#Image(filename='output/bus.jpg')
Image(filename='runs/detect/exp2/bus.jpg')

# %%
from IPython.display import Image
#Image(filename='output/zidane.jpg')
Image(filename='runs/detect/exp2/zidane.jpg')
